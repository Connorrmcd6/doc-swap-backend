# %%
import pandas as pd
import numpy as np
import random

# %%
data = pd.read_csv('2021_placements.csv')

# %%
data
# Out:
#                            Hospital  Posts  Applications
# 0                Addington Hospital     72            78
# 1                Boitumelo Hospital     16            53
# 2                  Bongani Hospital     18            43
# 3         Charlotte Maxeke Hospital     42            58
# 4   Chris Hani Baragwanath Hospital     90           123
# ..                              ...    ...           ...
# 60             Tshilidzine Hospital     16            31
# 61               Tygerberg Hospital     72           119
# 62                Victoria Hospital     18            71
# 63                 Witbank Hospital     30           424
# 64               Worcester Hospital     18           331
#
# [65 rows x 3 columns]

# %%
data['probability'] = data.Applications/data.Applications.sum()

# %%
data
# Out:
#                            Hospital  Posts  Applications  probability
# 0                Addington Hospital     72            78     0.006100
# 1                Boitumelo Hospital     16            53     0.004145
# 2                  Bongani Hospital     18            43     0.003363
# 3         Charlotte Maxeke Hospital     42            58     0.004536
# 4   Chris Hani Baragwanath Hospital     90           123     0.009619
# ..                              ...    ...           ...          ...
# 60             Tshilidzine Hospital     16            31     0.002424
# 61               Tygerberg Hospital     72           119     0.009306
# 62                Victoria Hospital     18            71     0.005553
# 63                 Witbank Hospital     30           424     0.033159
# 64               Worcester Hospital     18           331     0.025886
#
# [65 rows x 4 columns]

# %%
total_emails = data.Posts.sum()
emails = []

for i in range(total_emails):
    emails.append(f'user{i}@example.com')

# %%
placements = []

for i in data.index:
    posts = data.Posts[i]
    hospital = data.Hospital[i]
    placements.extend([hospital] * posts)

# %%
df_data ={"email": emails,
          'current_placement': placements}

current_placements_df = pd.DataFrame(df_data)
current_placements_df
# Out:
#                      email   current_placement
# 0        user0@example.com  Addington Hospital
# 1        user1@example.com  Addington Hospital
# 2        user2@example.com  Addington Hospital
# 3        user3@example.com  Addington Hospital
# 4        user4@example.com  Addington Hospital
# ...                    ...                 ...
# 2076  user2076@example.com  Worcester Hospital
# 2077  user2077@example.com  Worcester Hospital
# 2078  user2078@example.com  Worcester Hospital
# 2079  user2079@example.com  Worcester Hospital
# 2080  user2080@example.com  Worcester Hospital
#
# [2081 rows x 2 columns]

# %%
def select_random_hospitals(df, current, k=3):
    # Ensure the DataFrame has the expected columns
    if 'Hospital' not in df.columns or 'probability' not in df.columns:
        raise ValueError("DataFrame must contain 'Hospital' and 'probability' columns.")

    # Normalize the probabilities to sum up to 1
    df['probability'] = df['probability'] / df['probability'].sum()

    # Use random.choices to select k hospitals based on probabilities
    selected_hospitals = random.choices(df['Hospital'], df['probability'], k=k)

    # Check for duplicates or if current is in selected_hospitals
    if len(set(selected_hospitals)) != k or current in selected_hospitals:
        return select_random_hospitals(df, current, k)  # Return the result of the recursive call

    return selected_hospitals

# %%
for index, row in current_placements_df.iterrows():
    current =  current_placements_df.at[index, 'current_placement']
    
    choices = select_random_hospitals(data.iloc[:, [0, 3]], current)
    
    # Check if choices has at least three elements
    if len(choices) >= 3:
        current_placements_df.at[index, 'first_choice'] = choices[0]
        current_placements_df.at[index, 'second_choice'] = choices[1]
        current_placements_df.at[index, 'third_choice'] = choices[2]
    else:
        # Handle the case where select_random_hospitals returns fewer than three choices
        print(f"Error: Insufficient choices for row {index}.")
# Out:
# /var/folders/c7/dcyx4ss130ldp4lp9ph0v16c0000gn/T/ipykernel_24592/2797274722.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['probability'] = df['probability'] / df['probability'].sum()

# %%
current_placements_df.head(37)
# Out:
#                  email   current_placement  \
# 0    user0@example.com  Addington Hospital
# 1    user1@example.com  Addington Hospital
# 2    user2@example.com  Addington Hospital
# 3    user3@example.com  Addington Hospital
# 4    user4@example.com  Addington Hospital
# 5    user5@example.com  Addington Hospital
# 6    user6@example.com  Addington Hospital
# 7    user7@example.com  Addington Hospital
# 8    user8@example.com  Addington Hospital
# 9    user9@example.com  Addington Hospital
# 10  user10@example.com  Addington Hospital
# 11  user11@example.com  Addington Hospital
# 12  user12@example.com  Addington Hospital
# 13  user13@example.com  Addington Hospital
# 14  user14@example.com  Addington Hospital
# 15  user15@example.com  Addington Hospital
# 16  user16@example.com  Addington Hospital
# 17  user17@example.com  Addington Hospital
# 18  user18@example.com  Addington Hospital
# 19  user19@example.com  Addington Hospital
# 20  user20@example.com  Addington Hospital
# 21  user21@example.com  Addington Hospital
# 22  user22@example.com  Addington Hospital
# 23  user23@example.com  Addington Hospital
# 24  user24@example.com  Addington Hospital
# 25  user25@example.com  Addington Hospital
# 26  user26@example.com  Addington Hospital
# 27  user27@example.com  Addington Hospital
# 28  user28@example.com  Addington Hospital
# 29  user29@example.com  Addington Hospital
# 30  user30@example.com  Addington Hospital
# 31  user31@example.com  Addington Hospital
# 32  user32@example.com  Addington Hospital
# 33  user33@example.com  Addington Hospital
# 34  user34@example.com  Addington Hospital
# 35  user35@example.com  Addington Hospital
# 36  user36@example.com  Addington Hospital
#
#                                first_choice  \
# 0                        Dihlabeng Hospital
# 1                          Witbank Hospital
# 2         Robert Mangaliso Sobukwe Hospital
# 3                         Leratong Hospital
# 4                          Witbank Hospital
# 5                            Frere Hospital
# 6   General Justice Gizenga Mpanza Hospital
# 7            Ngwelezana Hospital, Empangeni
# 8     Klerksdorp-Tshepong Tertiary Hospital
# 9                        Cofimvaba Hospital
# 10                King Edward VIII Hospital
# 11         Nelson Mandela Academic Hospital
# 12                     Livingstone Hospital
# 13                        Pelonomi Hospital
# 14                           Frere Hospital
# 15                        Leratong Hospital
# 16                        Leratong Hospital
# 17                        Sebokeng Hospital
# 18                          Ermelo Hospital
# 19           Job Shimankana Tabane Hospital
# 20                   Potchefstroom Hospital
# 21                        Leratong Hospital
# 22                      Mapulaneng Hospital
# 23                     Livingstone Hospital
# 24        Robert Mangaliso Sobukwe Hospital
# 25        Prince Mshiyeni Memorial Hospital
# 26                        Leratong Hospital
# 27                         Witbank Hospital
# 28                     Livingstone Hospital
# 29                        Mokopane Hospital
# 30                        Leratong Hospital
# 31           Job Shimankana Tabane Hospital
# 32                          Grey's Hospital
# 33                           Paarl Hospital
# 34                     Livingstone Hospital
# 35                    Rob Ferreira Hospital
# 36  General Justice Gizenga Mpanza Hospital
#
#                             second_choice  \
# 0                    Livingstone Hospital
# 1                          Frere Hospital
# 2                          Paarl Hospital
# 3          Ngwelezana Hospital, Empangeni
# 4   Klerksdorp-Tshepong Tertiary Hospital
# 5                       Sebokeng Hospital
# 6                       Kalafong Hospital
# 7                    Lebowakgomo Hospital
# 8                    Livingstone Hospital
# 9                          Frere Hospital
# 10                      Kalafong Hospital
# 11                   Livingstone Hospital
# 12         Job Shimankana Tabane Hospital
# 13                         Frere Hospital
# 14                        George Hospital
# 15                        Themba Hospital
# 16  Klerksdorp-Tshepong Tertiary Hospital
# 17          Madadeni Hospital, New Castle
# 18                        Themba Hospital
# 19                   Tshilidzine Hospital
# 20                      Leratong Hospital
# 21                   Livingstone Hospital
# 22                      Leratong Hospital
# 23                  Rob Ferreira Hospital
# 24      Prince Mshiyeni Memorial Hospital
# 25                         Paarl Hospital
# 26                       Witbank Hospital
# 27                     Ladysmith Hospital
# 28      Prince Mshiyeni Memorial Hospital
# 29                       Bongani Hospital
# 30                     Tygerberg Hospital
# 31                Tambo Memorial Hospital
# 32                        George Hospital
# 33                  Helen Joseph Hospital
# 34  Klerksdorp-Tshepong Tertiary Hospital
# 35                         Frere Hospital
# 36          Madadeni Hospital, New Castle
#
#                                third_choice
# 0     Klerksdorp-Tshepong Tertiary Hospital
# 1                     New Somerset Hospital
# 2                        Dihlabeng Hospital
# 3   General Justice Gizenga Mpanza Hospital
# 4                        Worcester Hospital
# 5                    Potchefstroom Hospital
# 6                      Karl Bremer Hospital
# 7                            Frere Hospital
# 8                            Paarl Hospital
# 9                         Sebokeng Hospital
# 10                    Rob Ferreira Hospital
# 11                           Paarl Hospital
# 12                    Rob Ferreira Hospital
# 13                   Groote Schuur Hospital
# 14                          Letaba Hospital
# 15                          Grey's Hospital
# 16                           Paarl Hospital
# 17        Prince Mshiyeni Memorial Hospital
# 18                          Grey's Hospital
# 19                        Kalafong Hospital
# 20                          George Hospital
# 21                          Grey's Hospital
# 22                  Port Shepstone Hospital
# 23                           Paarl Hospital
# 24                        Kalafong Hospital
# 25    Klerksdorp-Tshepong Tertiary Hospital
# 26                       Dihlabeng Hospital
# 27         Nelson Mandela Academic Hospital
# 28                          George Hospital
# 29                  Port Shepstone Hospital
# 30               Dr George Mukhari Hospital
# 31                          Grey's Hospital
# 32                           Paarl Hospital
# 33                          George Hospital
# 34                    Rob Ferreira Hospital
# 35                         Tembisa Hospital
# 36           Ngwelezana Hospital, Empangeni

# %%
def find_duplicate_indices(df):
    # Initialize an empty list to store the indices of rows with duplicates
    duplicate_indices = []

    # Iterate through each row in the DataFrame
    for index, row in df.iterrows():
        # Convert the row values in the specified columns to a set to identify duplicates
        choices = set(row[['current_placement', 'first_choice', 'second_choice', 'third_choice']])
        
        # Check if the length of the set is less than the number of choices
        # This indicates that there are duplicate values in the choices
        if len(choices) < 4:
            duplicate_indices.append(index)
    
    return duplicate_indices

# %%
# Find and print the indices of rows with duplicate values
duplicate_indices = find_duplicate_indices(current_placements_df)
print(len(duplicate_indices))
# Out:
# 0

# %%
current_placements_df.to_csv("simulated_placements.csv", index=False)
